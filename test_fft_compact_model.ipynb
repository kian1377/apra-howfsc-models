# %%
import numpy as np
import cupy as cp
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import display, HTML, clear_output
display(HTML("<style>.container { width:90% !important; }</style>"))
from importlib import reload

import poppy

xp = cp if poppy.accel_math._USE_CUPY else np

import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
poppy_log.disabled = False

import warnings
warnings.filterwarnings("ignore")

from prop_models import compact2, agpm
reload(compact2)

from wfsc_1dm import utils

from imshows import *

wavelength_c = 750e-9*u.m
# Out:
# <style>.container { width:90% !important; }</style>

# %%
poppy_log.disabled = True

reload(compact2)
c = compact2.CORO()

c.npix = 256
c.oversample = 4
c.psf_pixelscale_lamD = 0.25
c.npsf = 128
c.CHARGE = 6

# c.norm = 100
# c.set_dm(np.random.randn(c.Nact,c.Nact)*2e-8)

c.USE_FPM = False
c.USE_FPM = True

c.propagate()
imshow2(xp.abs(c.wavefront)**2, xp.angle(c.wavefront), pxscl=c.psf_pixelscale_lamD, lognorm1=True)
# Out:
# pupil 26.0
# 6
# [2, 8, 32, 128, 512, 2048]
# [array([512., 512.])]
# [array([512., 512.]), array([8., 8.]), array([2., 2.]), array([0.5, 0.5]), array([0.125, 0.125]), array([0.03125, 0.03125])]
# 0
# Delta: 0.019230769230769232
# 1
# Max 465.5581728812658
# Delta: 0.004807692307692308
# 2
# Max 465.5581728812658
# Max 29.06407655618781
# Delta: 0.001201923076923077
# 3
# Max 465.5581728812658
# Max 29.06407655618781
# Max 29.064060996593984
# Delta: 0.00030048076923076925
# 4
# Max 465.5581728812658
# Max 29.06407655618781
# Max 29.064060996593984
# Max 29.064060746289865
# Delta: 7.512019230769231e-05
# 5
# Max 465.5581728812658
# Max 29.06407655618781
# Max 29.064060996593984
# Max 29.064060746289865
# Max 29.06406074237175
# Delta: 1.8780048076923078e-05
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 18
#      15 c.USE_FPM = False
#      16 c.USE_FPM = True
# ---> 18 c.propagate()
#      19 imshow2(xp.abs(c.wavefront)**2, xp.angle(c.wavefront), pxscl=c.psf_pixelscale_lamD, lognorm1=True)
#
# File ~/Projects/apra-howfsc-models/prop_models/compact2.py:245, in CORO.propagate(self)
#     241         self.wavefront *= WFE # apply WFE data
#     243         if self.USE_FPM:
#     244 #             self.wavefront = self.simple_vortex(self.wavefront)
# --> 245             self.wavefront = self.apply_vortex(self.wavefront)
#     246 #             in_val, out_val = (0.5, 6)
#     247 #             self.wavefront = falco.prop.mft_p2v2p(ensure_np_array(self.wavefront), self.CHARGE, self.npix/2, in_val, out_val)
#     248 #             self.wavefront = xp.array(self.wavefront)
#     250         self.wavefront *= LYOT # apply the Lyot stop
#
# File ~/Projects/apra-howfsc-models/prop_models/compact2.py:405, in CORO.apply_vortex(self, wavefront, q, scaling_factor, window_size)
#     403 for i, (mask, prop) in enumerate(zip(focal_masks, props)):
#     404     if i == 0:
# --> 405         lyot = prop(forward=True)
#     406     else:
#     407         focal = prop(wavefront)
#
# TypeError: CORO.fft() missing 1 required positional argument: 'wavefront'
