# %%
import numpy as np
import astropy.units as u

# %% [markdown]
# # Designing the Cassegrain
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
F = 295000*u.mm
D = 18500*u.mm
B = 15000*u.mm
M = (F-B)/D
print(M)

R1 = -2*D*F/(F-B)
R2 = -2*D*B/(F-B-D)
print(R1,R2)

K2 = -((M+1)/(M-1))**2
print(K2)
# Out:
# 15.135135135135135
# -38982.142857142855 mm -2122.3709369024855 mm
# -1.3030026066705909
