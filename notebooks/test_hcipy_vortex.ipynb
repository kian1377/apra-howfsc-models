# %%
import numpy as np
import scipy

import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import warnings
warnings.filterwarnings("ignore")

import poppy
import hcipy as hci

iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
calib_dir = iefc_dir/'calibration-data'

import misc_funs as misc

import hcipy_models as hcim
reload(hcim)

reload(hci)
npix = 256
oversample = 4
c = hcim.SVC(npix=npix, oversample=oversample)
# Out:
# [1024 1024] [0.02539062 0.02539062] [26. 26.]
# 6
# [2, 8, 32, 128, 512, 2048]
# [array([512., 512.])]
# 0
# Delta: [0.01923077 0.01923077]
# 1
# [0.159534 0.159534] [2048 2048]
# Max 352.61210727101786
# Delta: [0.00480769 0.00480769]
# 2
# [0.159534 0.159534] [2048 2048]
# Max 352.61210727101786
# [10.21017612 10.21017612] [128 128]
# Max 0.013525443712517704
# Delta: [0.00120192 0.00120192]
# 3
# [0.159534 0.159534] [2048 2048]
# Max 352.61210727101786
# [10.21017612 10.21017612] [128 128]
# Max 0.013525443712517704
# [40.8407045 40.8407045] [128 128]
# Max 0.0008453356185027089
# Delta: [0.00030048 0.00030048]
# 4
# [0.159534 0.159534] [2048 2048]
# Max 352.61210727101786
# [10.21017612 10.21017612] [128 128]
# Max 0.013525443712517704
# [40.8407045 40.8407045] [128 128]
# Max 0.0008453356185027089
# [163.36281799 163.36281799] [128 128]
# Max 5.283347693965557e-05
# Delta: [7.51201923e-05 7.51201923e-05]
# 5
# [0.159534 0.159534] [2048 2048]
# Max 352.61210727101786
# [10.21017612 10.21017612] [128 128]
# Max 0.013525443712517704
# [40.8407045 40.8407045] [128 128]
# Max 0.0008453356185027089
# [163.36281799 163.36281799] [128 128]
# Max 5.283347693965557e-05
