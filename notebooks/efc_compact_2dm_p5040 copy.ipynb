# %%
import numpy as np
import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import poppy
import logging, sys
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
poppy_log.disabled = True

from datetime import datetime
today = int(datetime.today().strftime('%Y%m%d'))

import warnings
warnings.filterwarnings("ignore")

import sys
# sys.path.insert(len(sys.path), 'home/apra/Projects/P5040/P5040_test_software/EFC/python_host')
sys.path.insert(len(sys.path), '/home/apra/Projects/P5040/P5040_test_software/EFC/python_host')
import efc_host_utils

import apra_pop_models
import apra_pop_models.fraunhofer_coro_2dm as fraunhofer
from apra_pop_models.math_module import xp, _scipy, ensure_np_array
import apra_pop_models.utils as utils
import apra_pop_models.efc_utils as efc_utils
import apra_pop_models.efc_2dm_embedded as efc
import apra_pop_models.pwp_embedded as pwp

from apra_pop_models.imshows import *

pupil_diam = 9.5*u.mm
wavelength_c = 650e-9*u.m

print(400/500*9.5 * 0.85, 6.5/ (400/500*9.5))

vortex = apra_pop_models.agpm.IdealAGPM(name='VVC', wavelength=wavelength_c, charge=6)

FN = 500
optimal_dm1_dm2 = (pupil_diam**2/(wavelength_c*FN)).to(u.mm)
display(optimal_dm1_dm2)

reload(utils)
wfe = utils.generate_wfe(diam=pupil_diam, npix=512, oversample=1,
                         opd_index=2.75, amp_index=2.75, 
                         opd_seed=123, amp_seed=1234,
                         opd_rms=20*u.nm, amp_rms=0.05, 
                         wavelength=wavelength_c)
CORO_WFE = poppy.ArrayOpticalElement(name='WFE', 
                                     transmission=xp.abs(wfe),
                                     opd=xp.angle(wfe)*wavelength_c.to_value(u.m)/(2*np.pi), 
                                     pixelscale=pupil_diam/(512*u.pix),)

wfe_mask = CORO_WFE.amplitude>0
rms_amp = xp.sqrt(xp.mean(CORO_WFE.amplitude[wfe_mask]**2))
rms_opd = xp.sqrt(xp.mean(CORO_WFE.opd[wfe_mask]**2))
imshow2(CORO_WFE.amplitude, CORO_WFE.opd,  f'{rms_amp:.3f}', f'{rms_opd:.3e}')
# Out:
# 6.46 0.8552631578947368
# <Quantity 277.69230769 mm>

# %%
poppy.accel_math.xp
# Out:
# <module 'cupy' from '/home/apra/miniconda3/envs/gpu311env/lib/python3.11/site-packages/cupy/__init__.py'>

# %%
type(xp.zeros(10))
# Out:
# cupy.ndarray

# %%
type()

# %%
import cupy
type(cupy.zeros((10,10)))
# Out:
# cupy.ndarray

# %%
reload(fraunhofer)
reload(utils)
model = fraunhofer.CORO(npix=512, oversample=8,
                        pupil_diam=9.5*u.mm,
                        RETRIEVED=CORO_WFE, 
                        )

psf = model.snap()
model.Imax_ref = xp.max(psf)

ref_psf = model.snap()

vortex_phasor = fraunhofer.make_vortex_phase_mask(model.N, 
                                                  singularity=None,
                                                  focal_length=500*u.mm, pupil_diam=model.pupil_diam, 
                                                  wavelength=model.wavelength_c)
model.FPM = vortex_phasor
ref_im = model.snap()

control_mask = efc_utils.create_annular_focal_plane_mask(model, inner_radius=3, outer_radius=10, plot=True)
Nmask = int(control_mask.sum())
print(Nmask)

mean_ni = xp.mean(ref_im[control_mask])

imshow3(ref_psf, ref_im, ref_im*control_mask, '', '', f'{mean_ni:.2e}', 
        lognorm=True, pxscl=model.psf_pixelscale_lamD, 
        vmin1=1e-5, vmin2=1e-8, vmin3=1e-8,
        cmap1='gist_heat', cmap2='gist_heat', cmap3='gist_heat')
# Out:
# Using the influence function supplied.
# Including factor of 2 from reflection when computing OPD.
# Using the influence function supplied.
# Including factor of 2 from reflection when computing OPD.
# 4576

# %%
poke_modes = efc_utils.create_all_poke_modes(model.dm_mask, ndms=2)

# %%
jac = efc.build_jacobian(model, 1e-9, poke_modes, control_mask, plot_responses=True,)
# Out:
# Calculating Jacobian:
# 	Calculated response for mode 1904/1904. Elapsed time=342.429 sec.
# Jacobian built in 342.429 sec

# %%
jac = fits.getdata(f'../jacobians/jac_{20240314}.fits')

# %%
jac.shape
# Out:
# (9152, 1904)

# %%
probe_mask = efc_utils.create_annular_focal_plane_mask(model, inner_radius=3, outer_radius=10, edge=0, plot=True)

# %%
reload(efc_utils)
Npairs = 2

probe_amp = 5e-9

probe_offset = (0,0)

probe_modes = efc_utils.create_fourier_probes(model, probe_mask, fourier_sampling=0.25, 
                                               shift=[(-6, 4), (6,4), (0,-6)], 
                                               nprobes=3,
                                               )
probes = probe_amp * probe_modes
imshow3(probes[0], probes[1], probes[2])

# %%
reload(efc_host_utils)
# Out:
# <module 'efc_host_utils' from '/home/apra/Projects/P5040/P5040_test_software/EFC/python_host/efc_host_utils.py'>

# %%
embedded_controller = efc_host_utils.EmbeddedController()

# %%
embedded_controller.send_jacobian(jac)

# %%
reload(pwp)
model.reset_dms()
E_est = pwp.run_pwp_bp(model, embedded_controller, control_mask, probes[:2], jac,
                            plot=True,
                            plot_est=True)
I_est = np.abs(E_est)**2
P_est = np.angle(E_est)

diff = ref_im*control_mask - I_est
vmax = xp.max(xp.concatenate([ref_im*control_mask, I_est]))
imshow3(ref_im*control_mask, I_est, xp.abs(diff),
        'Reference', 'Estimate', 'Difference with Model',
        lognorm=True, 
        vmax1=vmax, vmax2=vmax, vmax3=vmax,
        vmin1=1e-8, vmin2=1e-8, vmin3=1e-8)

# %%
model.reset_dms()

images = xp.array([ref_im])
dm1_commands = xp.array([model.get_dm1()])
dm2_commands = xp.array([model.get_dm2()])
regs = xp.array([])

# %%
reload(efc_host_utils)

# %%
reload(efc)

pwp_fun = pwp.run_pwp_bp

probe_amp = 1e-9
pwp_params = {
    'control_mask':control_mask,  
    'probes':probe_amp * probe_modes, 
    'use':'J', 
    'jacobian':jac,
    'plot_est':True
}

reg_fun = efc_utils.beta_reg
# reg_conds = -1
reg_conds = -2
# reg_conds = -2.5
# reg_conds = -3
# reg_conds = -3.5
# reg_conds = -4.5
# reg_conds = -5

images, dm1_commands, dm2_commands, regs = efc.run_efc_perfect(model, 
                                                               embedded_controller, 
                                                               reg_conds, 
                                                                poke_modes,
                                                                control_mask, 
                                                                # est_fun=pwp_fun, est_params=pwp_params,
                                                                Imax_unocc=1,
                                                                loop_gain=0.5, 
                                                                leakage=0.0,
                                                                iterations=3, 
                                                                plot_all=True, 
                                                                # plot_sms=True,
                                                                # plot_radial_contrast=True,
                                                                old_images=images,
                                                                old_dm1_commands=dm1_commands,
                                                                old_dm2_commands=dm2_commands,
                                                                old_regs=regs,
                                                                )
# Out:
# Beginning closed-loop EFC simulation.
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/Projects/P5040/P5040_test_software/EFC/python_host/efc_host_utils.py:95, in EmbeddedController.check_done(self)
#      94 try:
# ---> 95     acknowledgment = self.s.recv(3)
#      96     acknowledgment = acknowledgment.decode('utf-8')  # Convert the received bytes to a string
#
# TimeoutError: timed out
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Cell In[30], line 23
#      16 reg_conds = -2
#      17 # reg_conds = -2.5
#      18 # reg_conds = -3
#      19 # reg_conds = -3.5
#      20 # reg_conds = -4.5
#      21 # reg_conds = -5
# ---> 23 images, dm1_commands, dm2_commands, regs = efc.run_efc_perfect(model,
#      24                                                                embedded_controller,
#      25                                                                reg_conds,
#      26                                                                 poke_modes,
#      27                                                                 control_mask,
#      28                                                                 # est_fun=pwp_fun, est_params=pwp_params,
#      29                                                                 Imax_unocc=1,
#      30                                                                 loop_gain=0.5,
#      31                                                                 leakage=0.0,
#      32                                                                 iterations=3,
#      33                                                                 plot_all=True,
#      34                                                                 # plot_sms=True,
#      35                                                                 # plot_radial_contrast=True,
#      36                                                                 old_images=images,
#      37                                                                 old_dm1_commands=dm1_commands,
#      38                                                                 old_dm2_commands=dm2_commands,
#      39                                                                 old_regs=regs,
#      40                                                                 )
#
# File ~/Projects/apra-howfsc-models/apra_pop_models/efc_2dm_embedded.py:124, in run_efc_perfect(sysi, embedded_controller, reg_cond, calibration_modes, control_mask, est_fun, est_params, Imax_unocc, loop_gain, leakage, iterations, plot_all, plot_current, plot_sms, plot_radial_contrast, old_images, old_dm1_commands, old_dm2_commands, old_regs)
#     121 else:
#     122     starting_iteration = len(old_images) - 1
# --> 124 embedded_controller.do_ATA()
#     125 embedded_controller.do_decomposition(reg_cond)
#     127 for i in range(iterations):
#
# File ~/Projects/P5040/P5040_test_software/EFC/python_host/efc_host_utils.py:54, in timing_decorator.<locals>.wrapper(self, *args, **kwargs)
#      51 @functools.wraps(func)
#      52 def wrapper(self, *args, **kwargs):
#      53     start = timer()
# ---> 54     result = func(self, *args, **kwargs)
#      55     stop = timer()
#      56     elapsed_time = stop - start
#
# File ~/Projects/P5040/P5040_test_software/EFC/python_host/efc_host_utils.py:171, in EmbeddedController.do_ATA(self)
#     168 @timing_decorator
#     169 def do_ATA(self):
#     170     self.send_command(Commands.DO_ATA)
# --> 171     self.check_done()
#
# File ~/Projects/P5040/P5040_test_software/EFC/python_host/efc_host_utils.py:105, in EmbeddedController.check_done(self)
#     103         return 1
#     104 except socket.timeout:
# --> 105     raise Exception("Done not received within the specified timeout.")
#
# Exception: Done not received within the specified timeout.
