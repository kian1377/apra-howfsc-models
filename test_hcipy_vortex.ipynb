# %%
import numpy as np
import scipy

import astropy.units as u
from astropy.io import fits
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload
import time

import warnings
warnings.filterwarnings("ignore")

import poppy
import hcipy as hci

iefc_dir = Path('/groups/douglase/kians-data-files/roman-cgi-iefc-data')
calib_dir = iefc_dir/'calibration-data'

import misc_funs as misc

import hcipy_models as hcim
reload(hcim)

reload(hci)
npix = 256
oversample = 4
c = hcim.SVC(npix=npix, oversample=oversample)
# Out:
# [1024 1024] [0.02539062 0.02539062] [26. 26.]
# 6
# [2, 8, 32, 128, 512, 2048]
# [array([512., 512.])]
# 0
# 1
# 352.61210727101786
# 2
# 352.61210727101786
# 0.013525443712517704
# 3
# 352.61210727101786
# 0.013525443712517704
# 0.0008453356185027089
# 4
# 352.61210727101786
# 0.013525443712517704
# 0.0008453356185027089
# 5.283347693965557e-05
# 5
# 352.61210727101786
# 0.013525443712517704
# 0.0008453356185027089
# 5.283347693965557e-05
# 3.302092308725312e-06
