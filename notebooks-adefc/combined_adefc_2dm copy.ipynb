# %%
import numpy as np
import pandas as pd
import astropy.units as u
from astropy.io import fits
from matplotlib.colors import LogNorm
from matplotlib.patches import Rectangle, Circle
from pathlib import Path
from IPython.display import clear_output
from importlib import reload

import poppy
import logging, sys
import os
poppy_log = logging.getLogger('poppy')
poppy_log.setLevel('DEBUG')
logging.basicConfig(stream=sys.stdout, level=logging.INFO)
poppy_log.disabled = True

import warnings
warnings.filterwarnings("ignore")

import apra_pop_models
from apra_pop_models.math_module import xp, _scipy, ensure_np_array
import apra_pop_models.fresnel_2dm_34 as fresnel
import apra_pop_models.fraunhofer_2dm_34 as fraunhofer
import apra_pop_models.utils as utils
import apra_pop_models.props as props
from apra_pop_models.imshows import imshow1, imshow2, imshow3
import apra_pop_models.adefc_2dm as adefc
import apra_pop_models.efc_utils as efc_utils

from scipy.optimize import minimize
# Out:
# /home/brandon/Projects/apra-howfsc-models/apra_pop_models

# %%
reload(fresnel)
I = fresnel.CORO() # instantiate full fresnel model coronagraph instrument
I.use_opds = True

AMP, OPD = I.calc_pupil()
imshow2(AMP, OPD)
# Out:
# /home/brandon/Projects/apra-howfsc-models/apra_pop_models

# %%
reload(fresnel)
I = fresnel.CORO()
I.use_opds = True

I.use_vortex = False
ref_psf = I.snap()
I.Imax_ref = xp.max(ref_psf)
ref_psf /= I.Imax_ref
I.use_vortex = True
ref_coro_im = I.snap()

imshow2(ref_psf, ref_coro_im,
        pxscl=I.psf_pixelscale_lamDc, lognorm=True, vmin1=1e-5, vmin2=1e-10)
# Out:
# /home/brandon/code/apra-howfsc-models/apra_pop_models

# %%
reload(fraunhofer)
M = fraunhofer.MODEL()
# M.AMP = AMP
# M.OPD = OPD

test = os.path.join(os.path.expanduser('~'), 'code', 'embedded_howfsc', 'test')
c_file = os.path.join(test, 'aperture.csv')
# take the aperture file that was used to generate the C optical model planes

# Read the CSV file
df = pd.read_csv(c_file)

# Extract only the real column and convert to numpy array
real_values = df['real'].to_numpy()

# Reshape into 1000x1000 array
aperture = real_values.reshape(1000, 1000)
M.APERTURE = aperture # set the aperture to the aperture used in C optical model

# proceed with the rest of Kian's code
M.flip_dm = True
M.flip_lyot = True

imshow1(M.inf_fun, f'inf_fun', lognorm=False)
imshow1(M.dm_mask, f'dm_mask', lognorm=False)
imshow1(M.APERTURE, f'APERTURE', lognorm=False)



M.setattr('use_vortex', False)
model_psf = xp.abs(M.calc_wf()[0])**2
M.setattr('Imax_ref', xp.max(model_psf))
model_psf /= M.Imax_ref

M.setattr('use_vortex', True)
model_coro_im = xp.abs(M.calc_wf()[0])**2

imshow2(model_psf, model_coro_im,
        pxscl=M.psf_pixelscale_lamDc, lognorm=True, vmin1=1e-5, vmin2=1e-10)

dm1_command, dm2_command = ( xp.zeros((M.Nact, M.Nact)), xp.zeros((M.Nact, M.Nact)) )
# command = 50e-9*utils.make_f(h=10, w=6, shift=(0,0))
dm1_command = 10e-9*utils.make_fourier_command(x_cpa=17, y_cpa=17)
dm2_command = -10e-9*utils.make_fourier_command(x_cpa=17, y_cpa=17)

acts = xp.concatenate([dm1_command[M.dm_mask], dm2_command[M.dm_mask]])
fpwf = M.forward(acts, M.wavelength_c, use_vortex=0, fancy_plot=1)
fpwf = M.forward(acts, M.wavelength_c, use_vortex=1, fancy_plot=1)
# Out:
# dm_pxscl is 0.0096 mm / pix
# inf_sampling is 31.25
# Nsurf is 2048
# Nacts is 1904
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm copy.ipynb Cell 5 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> c_file = os.path.join(test, 'aperture.csv')
#       <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> # take the aperture file that was used to generate the C optical model planes
#       <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> # Read the CSV file
# ---> <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> df = pd.read_csv(c_file)
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a> # Extract only the real column and convert to numpy array
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#W4sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a> real_values = df['real'].to_numpy()
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/brandon/code/embedded_howfsc/test/aperture.csv'

# %%
imshow3(ref_psf, model_psf, xp.abs(ref_psf - model_psf), 
        lognorm1=True, lognorm2=True, lognorm3=True, vmax3=1, 
        vmin1=1e-5, vmin2=1e-5, vmin3=1e-5)

imshow3(ref_coro_im, model_coro_im, xp.abs(ref_coro_im - model_coro_im), 
        lognorm1=True, lognorm2=True, lognorm3=True, vmax3=xp.max(ref_coro_im), 
        vmin1=1e-8, vmin2=1e-8, vmin3=1e-8)

# %%
reload(efc_utils)
I.zero_dms()
iwa = 2.5
owa = 12
rot = 0
control_mask = efc_utils.create_annular_focal_plane_mask(I.npsf, I.psf_pixelscale_lamDc, irad=iwa, orad=owa, edge=None, rotation=rot)
mean_ni = xp.mean(ref_coro_im[control_mask])

imshow1(ref_coro_im*control_mask, f'Mean NI = {mean_ni:.3e}', lognorm=True)

# %%
import matplotlib.pyplot as plt

reload(fresnel)
I = fresnel.CORO() #instantiate the fresnel coronagraph for cross-checking?
I.use_opds = True
I.use_vortex = True # coronagraph on
reload(efc_utils)
I.zero_dms()
iwa = 2.5
owa = 12
rot = 0
control_mask = efc_utils.create_annular_focal_plane_mask(I.npsf, I.psf_pixelscale_lamDc, irad=iwa, orad=owa, edge=None, rotation=rot)

reload(fraunhofer) # make sure working copy of fraunhofer object is updated
from apra_pop_models import imshows
reload(imshows)
# current_acts = fits.getdata('example-data/ad_test_acts.fits')
M = fraunhofer.MODEL() # instantiate the fraunhofer Model
current_acts = xp.zeros(M.Nacts) # actuator command is all zeros
print(f"Nacts is {M.Nacts}")
# M.AMP = AMP
# M.OPD = OPD
print(f"npsf is {M.npsf}")
test = os.path.join(os.path.expanduser('~'), 'Projects', 'embedded_howfsc', 'test')
c_file = os.path.join(test, 'E_EP.csv')
df = pd.read_csv(c_file) # Read the CSV file
real_aperture = df['real'].to_numpy() # Extract only the real column and convert to numpy array
aperture = real_aperture.reshape(1000, 1000) # Reshape into 1000x1000 array

# initial condition of Fraunhofer model M is the same aperture used on C side
M.APERTURE = aperture
M.flip_dm = True
M.flip_lyot = True

imshow1(M.inf_fun, f'inf_fun', lognorm=False)
imshow1(M.dm_mask, f'dm_mask', lognorm=False)
imshow1(M.APERTURE, f'APERTURE', lognorm=False)

M.setattr('use_vortex', False) # no coronagraph in use
model_psf = xp.abs(M.calc_wf()[0])**2
print(f"shape of model_psf is {np.shape(model_psf)}")
M.setattr('Imax_ref', xp.max(model_psf))
model_psf /= M.Imax_ref # normalize the wavefront wrt maximum intensity without coronagraph
M.setattr('use_vortex', True) # coronagraph on

I.set_dm1(fraunhofer.acts_to_command(current_acts[:M.Nacts//2], M.dm_mask))
I.set_dm2(fraunhofer.acts_to_command(current_acts[M.Nacts//2:], M.dm_mask))

# E_ab = I.calc_wf()[0] * control_mask # "full" optical model gives us final wavefront in E_ab
E_ab = I.calc_wf() #* control_mask # "full" optical model gives us final wavefront in E_ab
print(f"shape of E_ab is {np.shape(E_ab)}")
print(f"shape of control_mask is {np.shape(control_mask)}")
imshow1(control_mask, f'control_mask', lognorm=False)
amp_E_ab = np.abs(E_ab)
phase_E_ab = np.angle(E_ab, deg=True)
imshow1(amp_E_ab, f'amp_E_ab', cmap='viridis')  # Added aspect='auto' for non-square matrices
imshow1(phase_E_ab, f'phase_E_ab', cmap='viridis')  # Added aspect='auto' for non-square matrices

r_cond = 1e-3

E_FP_nom, E_EP, E_DM2P, DM1_PHASOR, DM2_PHASOR = M.forward(current_acts, I.wavelength, use_vortex=True, return_ints=True,plot=True)
# current_acts = 0's

rmad_vars = {
    'current_acts':current_acts,
    'E_FP_nom':E_FP_nom,
    'E_EP':E_EP,
    'E_DM2P':E_DM2P,
    'DM1_PHASOR':DM1_PHASOR,
    'DM2_PHASOR':DM2_PHASOR,
    'E_ab':E_ab,
    'control_mask':control_mask,
    'wavelength':M.wavelength_c,
    'r_cond':r_cond,
}
amplitude = np.abs(E_EP)
phase = np.angle(E_EP, deg=True)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))
im1 = ax1.imshow(amplitude, cmap='viridis', aspect='auto')  # Added aspect='auto' for non-square matrices
ax1.set_title('Amplitude')
plt.colorbar(im1, ax=ax1)
im2 = ax2.imshow(phase, cmap='hsv', aspect='auto')  # Added aspect='auto' for non-square matrices
ax2.set_title('Phase (degrees)')
plt.colorbar(im2, ax=ax2)
plt.suptitle(f'E_EP after first forward pass')
plt.tight_layout()

plt.show()
del_acts = np.zeros(M.Nacts)
J, dJ_dA = fraunhofer.val_and_grad(
    del_acts, M, rmad_vars,
    verbose=True, 
    # plot=True, 
    fancy_plot=True,
)

dm1_grad = fraunhofer.acts_to_command(dJ_dA[:M.Nacts//2], M.dm_mask)
dm2_grad = fraunhofer.acts_to_command(dJ_dA[M.Nacts//2:], M.dm_mask)
imshow3(dm1_grad, dm2_grad, dm2_grad-dm1_grad)
# Out:
# /home/brandon/Projects/apra-howfsc-models/apra_pop_models
# dm_pxscl is 0.0096 mm / pix
# inf_sampling is 31.25
# Nsurf is 2048
# Nacts is 1904
# Nacts is 1904
# npsf is 256
# Entered the forward model!
# self.AMP is shape (1000, 1000)
# self.N is 1000
# shape of model_psf is (256, 256)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm copy.ipynb Cell 8 line 5
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> I.set_dm2(fraunhofer.acts_to_command(current_acts[M.Nacts//2:], M.dm_mask))
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a> # E_ab = I.calc_wf()[0] * control_mask # "full" optical model gives us final wavefront in E_ab
# ---> <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a> E_ab = I.calc_wf() #* control_mask # "full" optical model gives us final wavefront in E_ab
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=50'>51</a> print(f"shape of E_ab is {np.shape(E_ab)}")
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/Projects/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=51'>52</a> print(f"shape of control_mask is {np.shape(control_mask)}")
#
# File ~/Projects/apra-howfsc-models/apra_pop_models/fresnel_2dm_34.py:335, in CORO.calc_wf(self)
#     333 fosys_to_fpm, fosys_to_scicam = self.init_fosys()
#     334 ep_inwave = self.init_inwave()
# --> 335 _, fpm_wf = fosys_to_fpm.calc_psf(inwave=ep_inwave, normalize='none', return_final=True)
#     336 fpm_inwave = copy.copy(fpm_wf[0])
#     337 # print(fpm_inwave.wavelength)
#
# File ~/Projects/poppy/poppy/utils.py:1476, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1472 # Call the original function with any equivalencies in force.
#    1473 with add_enabled_equivalencies(self.equivalencies):
#    1474     # print("Args:   {}".format(bound_args.args))
#    1475     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1476     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/poppy_core.py:1736, in BaseOpticalSystem.calc_psf(self, wavelength, weight, save_intermediates, save_intermediates_what, display, return_intermediates, return_final, source, normalize, display_intermediates, progressbar, inwave)
#    1734 iterate_wrapper = utils.get_progressbar_wrapper(progressbar, nwaves=len(wavelength))
#    1735 for wlen, wave_weight in iterate_wrapper(zip(wavelength, normwts)):
# -> 1736     mono_psf, mono_intermediate_wfs = self.propagate_mono(
#    1737         wlen,
#    1738         retain_intermediates=retain_intermediates,
#    1739         retain_final=return_final,
#    1740         display_intermediates=display_intermediates,
#    1741         normalize=normalize,
#    1742         inwave=inwave
#    1743     )
#    1745     if outfits is None:
#    1746         # for the first wavelength processed, set up the arrays where we accumulate the output
#    1747         outfits = mono_psf
#
# File ~/Projects/poppy/poppy/utils.py:1476, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1472 # Call the original function with any equivalencies in force.
#    1473 with add_enabled_equivalencies(self.equivalencies):
#    1474     # print("Args:   {}".format(bound_args.args))
#    1475     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1476     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/poppy_core.py:1874, in BaseOpticalSystem.propagate_mono(self, wavelength, normalize, retain_intermediates, retain_final, display_intermediates, inwave)
#    1872     wavefront, intermediate_wfs = self.propagate(wavefront, **kwargs)
#    1873 else:
# -> 1874     wavefront = self.propagate(wavefront, **kwargs)
#    1875     intermediate_wfs = []
#    1877 if (not retain_intermediates) & retain_final:  # return the full complex wavefront of the last plane.
#
# File ~/Projects/poppy/poppy/fresnel.py:1296, in FresnelOpticalSystem.propagate(self, wavefront, normalize, return_intermediates, display_intermediates)
#    1293     s0 = time.time()
#    1295 # The actual propagation:
# -> 1296 wavefront.propagate_to(optic, distance)
#    1297 wavefront *= optic
#    1299 # Normalize if appropriate:
#
# File ~/Projects/poppy/poppy/utils.py:1476, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1472 # Call the original function with any equivalencies in force.
#    1473 with add_enabled_equivalencies(self.equivalencies):
#    1474     # print("Args:   {}".format(bound_args.args))
#    1475     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1476     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/fresnel.py:662, in FresnelWavefront.propagate_to(self, optic, distance)
#     659 # Apply Fresnel propagation for the specified distance, regardless of
#     660 # what type of plane is next
#     661 if distance != 0 * u.m:
# --> 662     self.propagate_fresnel(distance)
#     664 self.current_plane_index += 1
#     666 # Now we may do some further manipulations depending on the next plane
#
# File ~/Projects/poppy/poppy/utils.py:1476, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1472 # Call the original function with any equivalencies in force.
#    1473 with add_enabled_equivalencies(self.equivalencies):
#    1474     # print("Args:   {}".format(bound_args.args))
#    1475     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1476     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/fresnel.py:864, in FresnelWavefront.propagate_fresnel(self, delta_z, display_intermed)
#     862     _log.debug('  Plane to Plane Regime, dz=' + str(delta_z))
#     863     _log.debug('  Constant Pixelscale: {}'.format(self.pixelscale))
# --> 864     self._propagate_ptp(delta_z)
#     865 else:
#     866     # Plane wave to spherical. First use PTP to the waist, then WTS to Spherical
#     867     _log.debug('  Plane to Spherical Regime, inside Z_R to outside Z_R')
#
# File ~/Projects/poppy/poppy/utils.py:1476, in BackCompatibleQuantityInput.__call__.<locals>.unit_check_wrapper(*func_args, **func_kwargs)
#    1472 # Call the original function with any equivalencies in force.
#    1473 with add_enabled_equivalencies(self.equivalencies):
#    1474     # print("Args:   {}".format(bound_args.args))
#    1475     # print("KWArgs: {}".format(bound_args.kwargs))
# -> 1476     return wrapped_function(*bound_args.args, **bound_args.kwargs)
#
# File ~/Projects/poppy/poppy/fresnel.py:732, in FresnelWavefront._propagate_ptp(self, dz)
#     728 self._fft()
#     730 self.wavefront *= exp_t  # eq. 6.68
# --> 732 self._inv_fft()
#     733 self.z += dz
#     735 self.history.append("Propagated Plane-to-Plane, dz = " + str(z_direct))
#
# File ~/Projects/poppy/poppy/fresnel.py:435, in FresnelWavefront._inv_fft(self)
#     430     """
#     431     Apply normalized forward 2D Fast Fourier Transform to wavefront
#     432     """
#     433     self.wavefront = accel_math.fft_2d(self.wavefront, forward=True, fftshift=False)
# --> 435 def _inv_fft(self):
#     436     """
#     437     Apply normalized Inverse 2D Fast Fourier Transform to wavefront
#     438     """
#     439     self.wavefront = accel_math.fft_2d(self.wavefront, forward=False, fftshift=False)
#
# KeyboardInterrupt:

# %%
reload(fraunhofer)

current_acts = xp.zeros(M.Nacts)
# current_acts = fits.getdata('example-data/ad_test_acts.fits')

I.set_dm1(fraunhofer.acts_to_command(current_acts[:M.Nacts//2], M.dm_mask))
I.set_dm2(fraunhofer.acts_to_command(current_acts[M.Nacts//2:], M.dm_mask))
E_ab = I.calc_wf() * control_mask
coro_im = I.snap()
imshow3(coro_im, xp.abs(E_ab)**2, xp.angle(E_ab), lognorm1=True, lognorm2=True, cmap3='twilight')

E_FP_nom, E_EP, E_DM2P, DM1_PHASOR, DM2_PHASOR = M.forward(current_acts, I.wavelength, use_vortex=True, return_ints=True,)

rmad_vars = { 
    'current_acts':current_acts,
    'E_ab':E_ab, 
    'E_FP_nom':E_FP_nom,
    'E_EP':E_EP,
    'E_DM2P':E_DM2P,
    'DM1_PHASOR':DM1_PHASOR,
    'DM2_PHASOR':DM2_PHASOR,
    'control_mask':control_mask,
    'wavelength':I.wavelength,
    'r_cond':1e-3,
}

bfgs_tol = 1e-3
bfgs_opts = {
    'disp':True,
    # 'maxls':50,
    # 'ftol':1e-6,
    # 'gtol':1e-6,
}

del_acts0 = np.zeros(M.Nacts)
res = minimize(fraunhofer.val_and_grad, 
                jac=True, 
                x0=del_acts0,
                args=(M, rmad_vars, True, False), 
                method='L-BFGS-B',
                tol=bfgs_tol,
                options=bfgs_opts,
                )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm copy.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> bfgs_opts = {
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>     'disp':True,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a>     # 'maxls':50,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a>     # 'ftol':1e-6,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a>     # 'gtol':1e-6,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a> }
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a> del_acts0 = np.zeros(M.Nacts)
# ---> <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=35'>36</a> res = minimize(fraunhofer.val_and_grad,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a>                 jac=True,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a>                 x0=del_acts0,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=38'>39</a>                 args=(M, rmad_vars, True, False),
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=39'>40</a>                 method='L-BFGS-B',
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=40'>41</a>                 tol=bfgs_tol,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=41'>42</a>                 options=bfgs_opts,
#      <a href='vscode-notebook-cell://ssh-remote%2B18.18.33.51/home/brandon/code/apra-howfsc-models/notebooks-adefc/combined_adefc_2dm%20copy.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=42'>43</a>                 )
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_minimize.py:731, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     728     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     729                              **options)
#     730 elif meth == 'l-bfgs-b':
# --> 731     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     732                            callback=callback, **options)
#     733 elif meth == 'tnc':
#     734     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     735                         **options)
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_lbfgsb_py.py:347, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     344         iprint = disp
#     346 # _prepare_scalar_function can use bounds=None to represent no bounds
# --> 347 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     348                               bounds=bounds,
#     349                               finite_diff_rel_step=finite_diff_rel_step)
#     351 func_and_grad = sf.fun_and_grad
#     353 fortran_int = _lbfgsb.types.intvar.dtype
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_optimize.py:288, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     284     bounds = (-np.inf, np.inf)
#     286 # ScalarFunction caches. Reuse of fun(x) during grad
#     287 # calculation reduces overall function evaluations.
# --> 288 sf = ScalarFunction(fun, x0, args, grad, hess,
#     289                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     291 return sf
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:222, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     219     finite_diff_options["as_linear_operator"] = True
#     221 # Initial function evaluation
# --> 222 self._update_fun()
#     224 # Initial gradient evaluation
#     225 self._wrapped_grad, self._ngev = _wrapper_grad(
#     226     grad,
#     227     fun=self._wrapped_fun,
#     228     args=args,
#     229     finite_diff_options=finite_diff_options
#     230 )
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:294, in ScalarFunction._update_fun(self)
#     292 def _update_fun(self):
#     293     if not self.f_updated:
# --> 294         fx = self._wrapped_fun(self.x)
#     295         if fx < self._lowest_f:
#     296             self._lowest_x = self.x
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_differentiable_functions.py:20, in _wrapper_fun.<locals>.wrapped(x)
#      16 ncalls[0] += 1
#      17 # Send a copy because the user may overwrite it.
#      18 # Overwriting results in undefined behaviour because
#      19 # fun(self.x) will change self.x, with the two no longer linked.
# ---> 20 fx = fun(np.copy(x), *args)
#      21 # Make sure the function returns a true scalar
#      22 if not np.isscalar(fx):
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_optimize.py:79, in MemoizeJac.__call__(self, x, *args)
#      77 def __call__(self, x, *args):
#      78     """ returns the function value """
# ---> 79     self._compute_if_needed(x, *args)
#      80     return self._value
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/scipy/optimize/_optimize.py:73, in MemoizeJac._compute_if_needed(self, x, *args)
#      71 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      72     self.x = np.asarray(x).copy()
# ---> 73     fg = self.fun(x, *args)
#      74     self.jac = fg[1]
#      75     self._value = fg[0]
#
# File ~/code/apra-howfsc-models/apra_pop_models/fraunhofer_2dm_34.py:260, in val_and_grad(del_acts, M, rmad_vars, verbose, plot, fancy_plot)
#     256 E_ab_l2norm = E_ab[control_mask].dot(E_ab[control_mask].conjugate()).real
#     258 # Compute E_dm using the forward DM model
#     259 # E_FP_nom, E_EP, E_DM2P, DM1_PHASOR, DM2_PHASOR = M.forward(actuators, wavelength, use_vortex=True, return_ints=True,) # make sure to do the array indexing
# --> 260 E_FP_delDMs, E_EP, E_DM2P, DM1_PHASOR, DM2_PHASOR = M.forward(current_acts+del_acts, wavelength, use_vortex=True) # make sure to do the array indexing
#     261 E_DMs = E_FP_delDMs - E_FP_nom
#     263 # compute the cost function
#
# File ~/code/apra-howfsc-models/apra_pop_models/fraunhofer_2dm_34.py:162, in MODEL.forward(self, actuators, wavelength, use_vortex, return_ints, plot, fancy_plot)
#     160 fp_wf_lres = props.fft(lres_wf)
#     161 fp_wf_lres *= self.vortex_lres * (1 - self.lres_window) # apply low res FPM and inverse Tukey window
# --> 162 pupil_wf_lres = props.ifft(fp_wf_lres)
#     163 pupil_wf_lres = utils.pad_or_crop(pupil_wf_lres, self.N)
#     164 if plot: imshows.imshow2(xp.abs(pupil_wf_lres), xp.angle(pupil_wf_lres), 'Vortex FFT WF', npix=1.5*self.npix)
#
# File ~/code/apra-howfsc-models/apra_pop_models/props.py:24, in ifft(arr)
#      23 def ifft(arr):
# ---> 24     return xp.fft.fftshift(xp.fft.ifft2(xp.fft.ifftshift(arr)))
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/numpy/fft/_pocketfft.py:1107, in ifft2(a, s, axes, norm)
#    1017 @array_function_dispatch(_fftn_dispatcher)
#    1018 def ifft2(a, s=None, axes=(-2, -1), norm=None):
#    1019     """
#    1020     Compute the 2-dimensional inverse discrete Fourier Transform.
#    1021
#    (...)
#    1105
#    1106     """
# -> 1107     return _raw_fftnd(a, s, axes, ifft, norm)
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/numpy/fft/_pocketfft.py:707, in _raw_fftnd(a, s, axes, function, norm)
#     705 itl.reverse()
#     706 for ii in itl:
# --> 707     a = function(a, n=s[ii], axis=axes[ii], norm=norm)
#     708 return a
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/numpy/fft/_pocketfft.py:316, in ifft(a, n, axis, norm)
#     314     n = a.shape[axis]
#     315 inv_norm = _get_backward_norm(n, norm)
# --> 316 output = _raw_fft(a, n, axis, False, False, inv_norm)
#     317 return output
#
# File ~/miniconda3/envs/be311cpu/lib/python3.11/site-packages/numpy/fft/_pocketfft.py:73, in _raw_fft(a, n, axis, is_real, is_forward, inv_norm)
#      71 else:
#      72     a = swapaxes(a, axis, -1)
# ---> 73     r = pfi.execute(a, is_real, is_forward, fct)
#      74     r = swapaxes(r, axis, -1)
#      75 return r
#
# KeyboardInterrupt:

# %%
old_dm1 = fraunhofer.acts_to_command(current_acts[:M.Nacts//2], I.dm_mask)
old_dm2 = fraunhofer.acts_to_command(current_acts[M.Nacts//2:], I.dm_mask)
del_dm1 = fraunhofer.acts_to_command(res.x[:M.Nacts//2], I.dm_mask)
del_dm2 = fraunhofer.acts_to_command(res.x[M.Nacts//2:], I.dm_mask)

I.set_dm1(old_dm1 + del_dm1)
I.set_dm2(old_dm2 + del_dm2)
new_im = I.snap()

print(xp.mean(coro_im[control_mask]), xp.mean(new_im[control_mask]))
imshow3(old_dm1, old_dm2, coro_im, lognorm3=True, pxscl3=I.psf_pixelscale_lamDc, vmin3=1e-10,)
imshow3(del_dm1, del_dm2, new_im, lognorm3=True, pxscl3=I.psf_pixelscale_lamDc, vmin3=1e-10,)
# Out:
# 2.658089214049493e-06 2.1289520255306057e-08

# %%
utils.save_fits('ad_test_acts.fits', res.x)
# Out:
# Saved data to:  ad_test_acts.fits

# %%
I.zero_dms()
data = {
    # 'ref_im':ref_coro_im, 
    'images':[ref_coro_im],
    'efields':[],
    'dm1_commands':[],
    'del_dm1_commands':[],
    'dm2_commands':[],
    'del_dm2_commands':[],
    'reg_conds':[],
    'bfgs_tols':[],
    'pixelscale':I.psf_pixelscale_lamDc,
    'control_mask':control_mask, 
}

# %%
reload(fraunhofer)
reload(adefc)

r_cond = 1e-2
# r_cond = 1e-3
# r_cond = 1e-4
# r_cond = 1e-5
# r_cond = 1e-6

bfgs_tol = 1e-2
bfgs_tol = 1e-3
# bfgs_tol = 1e-4
# bfgs_tol = 1e-5

bfgs_opts = {
    'disp':True,
    # 'ftol':1e-6,
    # 'gtol':1e-6,
}

data = adefc.run(
    I, 
    M, 
    fraunhofer.val_and_grad, 
    control_mask, 
    data,
    Nitr=3, 
    reg_cond=r_cond,
    bfgs_tol=bfgs_tol,
    bfgs_opts=bfgs_opts,
    gain=1,
)
# Out:
# Running estimation algorithm ...
# Computing EFC command with L-BFGS
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1904     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00000D+00    |proj g|=  8.08443D+06
#  This problem is unconstrained.
# At iterate    1    f=  4.59368D-01    |proj g|=  5.67089D+06
#
# At iterate    2    f=  1.91328D-01    |proj g|=  1.30627D+06
#
# At iterate    3    f=  1.51675D-01    |proj g|=  9.55339D+05
#
# At iterate    4    f=  1.08504D-01    |proj g|=  8.78303D+05
#
# At iterate    5    f=  6.99378D-02    |proj g|=  7.38671D+05
#
# At iterate    6    f=  6.26608D-02    |proj g|=  1.66679D+06
#
# At iterate    7    f=  3.35555D-02    |proj g|=  4.60969D+05
#
# At iterate    8    f=  2.88729D-02    |proj g|=  2.55532D+05
#
# At iterate    9    f=  2.37570D-02    |proj g|=  2.17372D+05
#
# At iterate   10    f=  2.20384D-02    |proj g|=  8.43264D+05
#
# At iterate   11    f=  1.80344D-02    |proj g|=  2.73225D+05
#
# At iterate   12    f=  1.66491D-02    |proj g|=  1.40130D+05
#
# At iterate   13    f=  1.53667D-02    |proj g|=  2.34878D+05
#
# At iterate   14    f=  1.34287D-02    |proj g|=  3.30802D+05
#
# At iterate   15    f=  1.25832D-02    |proj g|=  2.08477D+05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1904     15     20      1     0     0   2.085D+05   1.258D-02
#   F =   1.2583191492231072E-002
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Running estimation algorithm ...
# Computing EFC command with L-BFGS
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1904     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00000D+00    |proj g|=  4.77079D+07
#  This problem is unconstrained.
# At iterate    1    f=  7.56858D-01    |proj g|=  2.99854D+07
#
# At iterate    2    f=  6.80013D-01    |proj g|=  2.05413D+07
#
# At iterate    3    f=  5.91581D-01    |proj g|=  1.37599D+07
#
# At iterate    4    f=  5.19040D-01    |proj g|=  1.71390D+07
#
# At iterate    5    f=  4.50801D-01    |proj g|=  2.35595D+07
#
# At iterate    6    f=  3.95407D-01    |proj g|=  9.87264D+06
#
# At iterate    7    f=  3.65426D-01    |proj g|=  7.73358D+06
#
# At iterate    8    f=  3.28208D-01    |proj g|=  1.00297D+07
#
# At iterate    9    f=  3.15913D-01    |proj g|=  2.46400D+07
#
# At iterate   10    f=  2.76580D-01    |proj g|=  7.97586D+06
#
# At iterate   11    f=  2.56748D-01    |proj g|=  5.84780D+06
#
# At iterate   12    f=  2.38711D-01    |proj g|=  8.28631D+06
#
# At iterate   13    f=  2.12467D-01    |proj g|=  1.47310D+07
#
# At iterate   14    f=  1.98798D-01    |proj g|=  8.55617D+06
#
# At iterate   15    f=  1.86755D-01    |proj g|=  4.96873D+06
#
# At iterate   16    f=  1.80478D-01    |proj g|=  1.20186D+07
#
# At iterate   17    f=  1.72917D-01    |proj g|=  4.58439D+06
#
# At iterate   18    f=  1.66123D-01    |proj g|=  3.35205D+06
#
# At iterate   19    f=  1.59043D-01    |proj g|=  5.27903D+06
#
# At iterate   20    f=  1.58157D-01    |proj g|=  6.48695D+06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1904     20     24      1     0     0   6.487D+06   1.582D-01
#   F =  0.15815708096588721
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# Running estimation algorithm ...
# Computing EFC command with L-BFGS
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =         1904     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.00000D+00    |proj g|=  1.27836D+08
#  This problem is unconstrained.
# At iterate    1    f=  9.09679D-01    |proj g|=  4.79044D+07
#
# At iterate    2    f=  8.80426D-01    |proj g|=  3.85268D+07
#
# At iterate    3    f=  8.08795D-01    |proj g|=  3.72642D+07
#
# At iterate    4    f=  7.99097D-01    |proj g|=  8.13676D+07
#
# At iterate    5    f=  7.61225D-01    |proj g|=  2.54416D+07
#
# At iterate    6    f=  7.39557D-01    |proj g|=  2.04852D+07
#
# At iterate    7    f=  7.12831D-01    |proj g|=  3.09665D+07
#
# At iterate    8    f=  6.75144D-01    |proj g|=  3.27532D+07
#
# At iterate    9    f=  6.18589D-01    |proj g|=  5.54514D+07
#
# At iterate   10    f=  5.88937D-01    |proj g|=  3.90827D+07
#
# At iterate   11    f=  5.57694D-01    |proj g|=  2.29868D+07
#
# At iterate   12    f=  5.32536D-01    |proj g|=  2.72069D+07
#
# At iterate   13    f=  5.16591D-01    |proj g|=  4.16146D+07
#
# At iterate   14    f=  4.99260D-01    |proj g|=  3.32279D+07
#
# At iterate   15    f=  4.84174D-01    |proj g|=  2.40047D+07
#
# At iterate   16    f=  4.73890D-01    |proj g|=  2.82150D+07
#
# At iterate   17    f=  4.65902D-01    |proj g|=  2.90925D+07
#
# At iterate   18    f=  4.61678D-01    |proj g|=  2.36206D+07
#
# At iterate   19    f=  4.59110D-01    |proj g|=  2.08959D+07
#
# At iterate   20    f=  4.57495D-01    |proj g|=  2.12417D+07
#
# At iterate   21    f=  4.57225D-01    |proj g|=  2.62641D+07
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#  1904     21     27      1     0     0   2.626D+07   4.572D-01
#   F =  0.45722456439549858
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
reload(adefc)
adefc.plot_data(data, vmin=1e-11)
